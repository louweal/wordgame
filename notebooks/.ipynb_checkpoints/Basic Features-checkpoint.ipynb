# %% [markdown]
# # Words and Brains - Basic Features
#
# Welcome to my WordGame project! In this second notebook, ...
#
# First we do the usual library imports and stuff.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # plotting
import seaborn as sns # data visualization

from subprocess import check_output
#print(check_output(["ls", "../input/wordgame"]).decode("utf8"))

# color palette for plotting
pal = sns.color_palette("Paired", 10)

# %% [markdown]
# Now, let's open up the dataset.

# %%
#df = pd.read_csv('../input/wordgame/wordgame_20170628.csv', dtype='object')
df = pd.read_csv('../data/processed/wordgame_20170628_freq.csv', dtype='object')

#again define a alphabetical list of source names
sources_list = ['aspiecentral','atu2','bleeping_computer', 'classic_comics','ecig','gog','learn_english','sas','the_fishy','wrongplanet']

#
df['sourceID'] = df['sourceID'].astype(int)
print(df.dtypes)

#print dataset dimensions
print(df.shape)

#print first 5 rows
df.head()
# Out:
# author      object
# word1       object
# word2       object
# source      object
# pair        object
# pf          object
# pf10        object
# sourceID     int64
# tf          object
# tf10        object
# df          object
# tfidf10     object
# pfidf10     object
# dtype: object
# (334036, 13)
#   author   word1       word2       source               pair  \
# 0   1203  jailed  imprisoned         ecig  jailed:imprisoned
# 1   5839      me   liverbird  wrongplanet       me:liverbird
# 2   2962   reach          up          sas           reach:up
# 3   1066    owie    band-aid         ecig      owie:band-aid
# 4   5006   water       river  wrongplanet        water:river
#
#                        pf                    pf10  sourceID  \
# 0  2.9936893029493827e-06   5.243013684265716e-05         4
# 1  2.9936893029493827e-06   3.328451604313673e-05         9
# 2  2.9936893029493827e-06  2.5949087889560682e-05         7
# 3  2.9936893029493827e-06   5.243013684265716e-05         4
# 4   4.490533954424074e-05  0.00026627612834509385         9
#
#                        tf                    tf10  df                 tfidf10  \
# 0   2.095582512064568e-05    0.000314580821055943   2   0.0005636531649645221
# 1   0.0009669616448526506   0.0015643722540274263  10    0.001084340217225317
# 2  3.5924271635392595e-05   0.0001297454394478034   5  0.00014253993417600094
# 3   8.981067908848149e-06  0.00010486027368531432   2  0.00018788438832150736
# 4   0.0019429043576141493    0.004559978697909733  10   0.0031607363778695416
#
#                   pfidf10
# 0   9.394219416075368e-05
# 1  2.3071068451602493e-05
# 2  2.8507986835200192e-05
# 3   9.394219416075368e-05
# 4  0.00018456854761281994

# %% [markdown]
# ## Word length
# We are now ready to extract our first feature, which will be the word length. I do not expect any differences between NT'ers and ASD'ers, although I'm curious to what is the average length of English words.

# %%
df['word1'] = df['word1'].astype(str)
df['word2'] = df['word2'].astype(str)

df['len1'] = df['word1'].apply(lambda x:len(x))
df['len2'] = df['word2'].apply(lambda x:len(x))

print("Longest word: " +str(df['len1'].max()))

plt.figure(figsize=(11, 6))
for i in range(0,10):
    s = df[df['sourceID']==i]
    g = sns.kdeplot(s['len1'], alpha=0.6, label=sources_list[i], color=pal[i])  
g = sns.kdeplot(df['len1'], color="black", label="all data")  
plt.xlabel('word length')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([0,25])
plt.show()
# Out:
# Longest word: 200

# %% [markdown]
# english average is 5. -> ecig.

# %% [markdown]
# ## Word length difference
# We can also look at the difference between the word lenght of word1 and word2.

# %%
df['d_len'] = df.len1 - df.len2

plt.figure(figsize=(22, 6))
plt.subplot(1,2,1)
for i in range(0,10):
    s = df[df['sourceID']==i]
    g = sns.kdeplot(s['d_len'], alpha=0.4, label=sources_list[i], color=pal[i])  
g = sns.kdeplot(df['d_len'], color="black", label="all data")  
plt.xlabel('word length difference')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([-15,15])

plt.subplot(1,2,2)
g = sns.kdeplot(df['len1'], df['len2'], shade=True)  
plt.xlabel('length word1')
plt.ylabel('length word2')
axes = plt.gca()
axes.set_xlim([1,13])
axes.set_ylim([1,13])
plt.show()

# %% [markdown]
# Nice!

# %% [markdown]
# ## Levenshtein Distance
# ...

# %%
import Levenshtein

def levenshtein(r):
	return Levenshtein.distance(r.word1, r.word2)

#calculate levenstein distance on each row and add to dataframe
df['edit'] = df.apply(levenshtein, axis=1)

#print mean edit distance
print("Mean edit distance: "+ str(df['edit'].mean()))

#Plot
plt.figure(figsize=(11, 6))
for i in range(0,10):
    s = df[df['sourceID']==i]
    g = sns.kdeplot(s['edit'], alpha=0.4, label=sources_list[i], color=pal[i])  
g = sns.kdeplot(df['edit'], color="black", label="all data")  
plt.title('Histogram of edit distance')
plt.xlabel('Edit distance')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([0,25])
#axes.set_ylim([0,0.015])
plt.show()
# Out:
# Mean edit distance: 6.82767126897

# %% [markdown]
# maybe compare mean word length with mean edit?

# %% [markdown]
# # Save

# %%
#set output filename
outfile = "../data/processed/wordgame_20170628_freq_basic.csv"

# write rows to file
df.to_csv(outfile, sep=',', index=False)
