# %% [markdown]
# # Wordgame Word2Vec features
# Welcome to the second notebook in my wordgame project. In this notebook our goal is to extract a the similarity of the word pairs based on Word2Vec. Word2Vec is a model..
#
# a) open tail
# b) compute sim
# 1) Compare sim with sim of random word pairs (shift)
# 2) Plot all sim dists
# 3) Plot specific. word

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.palplot(sns.color_palette("Set2", 10))

df = pd.read_csv('../data/processed/wordgame_20170628_basicfeatures.csv', dtype={'nt': np.bool, 'word1':str, 'word2':str})

df.head()
# Out:
#    author   word1       word2       source  sourceID     nt  len1  len2  \
# 0    1203  jailed  imprisoned         ecig         4   True     6    10
# 1    5839      me   liverbird  wrongplanet         9  False     2     9
# 2    2962   reach          up          sas         7   True     5     2
# 3    1066    owie    band-aid         ecig         4   True     4     8
# 4    5006   water       river  wrongplanet         9  False     5     5
#
#    d_len  edit    n_edit
# 0      4     7  0.051471
# 1      7     8  0.094118
# 2      3     5  0.172414
# 3      4     7  0.087500
# 4      0     3  0.060000

# %%
from gensim.models.keyedvectors import KeyedVectors

w2v_model = KeyedVectors.load_word2vec_format('../data/external/GoogleNews-vectors-negative300.bin', binary=True)
print('Loaded word embeddings')
# Out:
# Loaded word embeddings

# %%
#
def inVocab(r):
    if (r.word1 in w2v_model.vocab) & (r.word2 in w2v_model.vocab):    
        return True
    return False

df['invoc'] = df.apply(inVocab, axis=1)

#
def calcVec(r): 
    if r.invoc:
        return (w2v_model.word_vec(r.word1), w2v_model.word_vec(r.word2)) 
    else:
        return (0,0)
    
df['wv1'],df['wv2'] = zip(*df.apply(calcVec, axis=1))

#
def similarity(r):
    if r.invoc:
        return w2v_model.similarity(r.word1, r.word2)
    else:
        return 0
    
df['sim'] = df.apply(similarity, axis=1) 
print("finished")
# Out:
# finished

# %%
# remove a words (pairs) that are not in vocabulary
df = df[df['invoc']]
print("Number of remaining word pairs: " +str(len(df)))
print("Mean similariy score: " +str(df['sim'].mean()))
# Out:
# Number of remaining word pairs: 272708
# Mean similariy score: 0.268906919797

# %% [markdown]
# 81% of pairs in vocabulary. sim = 0.27

# %%
plt.figure(figsize=(8, 4))
#sns.kdeplot(nt, label="NT")
#sns.kdeplot(asd, label="ASD")
for i in range(0,10,1):
    s = df[df['sourceID']==i]
    tfidf = s.sim
    sns.kdeplot(tfidf, alpha=0.7, label=s.iloc[0]['source'])  
plt.title('Histogram of similarity')
plt.xlabel('Similarity')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([-0.1,1.1])
plt.show()
# Out:
# Number of NT word pairs: 214613
# 	Mean similarity: 0.26703453666
# Number of ASD word pairs: 58095
# 	Mean similarity: 0.275823827657

# %% [markdown]
# ecig..

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE

#remove..
sns.palplot(sns.color_palette("Set2", 10))

word_list1 = ['me','you','king', 'queen','man','woman']
#word_list1 = ['paris', 'france', 'london', 'england', 'madrid', 'spain', 'rome', 'italy', 'berlin', 'germany']
#word_list1 = ['two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten','eleven','twelve','thirteen']

sample1 = df[(df['word1'].isin(word_list1))][:]
sample1['c'] = sample1.groupby(['word2'])['word2'].transform('count') 
sample2 = df[(df['word2'].isin(word_list1))][:]
sample2['c'] = sample2.groupby(['word1'])['word1'].transform('count') 
#sample2 = df[(df['word1'].isin(word_list2))]
#sample3 = df[(df['word1'].isin(word_list3))]

print("Number of pairs in sample 1: "+ str(len(sample1)))
#print("Number of pairs in sample 2: "+ str(len(sample2)))
#print("Number of pairs in sample 3: "+ str(len(sample3)))
# Out:
# Number of pairs in sample 1: 1281

# %%
# Compute reduced word-vectors

#sample1['word'] = 
#word_vecs1 = sample1[~sample['word1'].isin(word_list1) | 

model = TSNE(random_state=42).fit_transform(sample1['wv2'].tolist()) 
sample1['x'] = model[:,0]
sample1['y'] = model[:,1]

model = TSNE(random_state=42).fit_transform(sample2['wv1'].tolist()) 
sample2['x'] = model[:,0]
sample2['y'] = model[:,1]


#reduced2 = TSNE(random_state=42).fit_transform(sample2['wv2'].tolist()) 
#reduced3 = TSNE(random_state=42).fit_transform(sample3['wv2'].tolist()) 
print("Finished")
# Out:
# Finished

# %%
#red = sample['red']
sample1 = sample1.drop_duplicates(subset=['word2'])
print(len(sample1))
sample2 = sample2.drop_duplicates(subset=['word1'])
print(len(sample2))

#sample1['col'] = sample1['nt'].apply(lambda x:pal[x])

plt.figure(figsize=(20, 20))

fig, ax = plt.subplots()
ax.scatter(sample1.x, sample1.y, marker='o', s=3*sample1.c, c=pal[3], alpha=0.5, label='...')
for i in range(0,len(sample1)):
    if(sample1.word2.iloc[i] in word_list1):
        ax.annotate(sample1.word2.iloc[i], (sample1.x.iloc[i], sample1.y.iloc[i]))

ax.scatter(sample2.x, sample2.y, marker='o', s=3*sample2.c, c=pal[2], alpha=0.5, label='...')
for i in range(0,len(sample2)):
    if(sample2.word1.iloc[i] in word_list1):
        ax.annotate(sample2.word1.iloc[i], (sample2.x.iloc[i], sample2.y.iloc[i]))
        
plt.title('Scatterplot of reduced word-vectors: Sample 1')
plt.legend(loc='upper right')
plt.show()
# Out:
# 487
# 613

# %% [markdown]
# you man/woman
# me king/queen
# :P

# %% [markdown]
# plot all learn-english and comics data? if possible... freq>10?
#
# or all frequent word PAIRS
