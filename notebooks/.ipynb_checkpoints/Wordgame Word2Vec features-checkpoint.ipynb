# %% [markdown]
# # Wordgame Word2Vec features
# Welcome to the second notebook in my wordgame project. In this notebook our goal is to extract a the similarity of the word pairs based on Word2Vec. Word2Vec is a model..
#
# a) open tail
# b) compute sim
# 1) Compare sim with sim of random word pairs (shift)
# 2) Plot all sim dists
# 3) Plot specific. word

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('../data/processed/wordgame_20170628_basicfeatures.csv', dtype={'nt': np.bool, 'word1':str, 'word2':str})

df.tail()
# Out:
#         author        word1        word2             source  sourceID     nt  \
# 334031    4298         down        below                sas         7   True
# 334032    1732     unneeded  superfluous                gog         5   True
# 334033     200         good     riddance       aspiecentral         0  False
# 334034     746  tempurpedic     mattress  bleeping_computer         2   True
# 334035    1508       offend        offer                gog         5   True
#
#         len1  len2  d_len  edit    n_edit
# 334031     4     5      1     4  0.097561
# 334032     8    11      3    10  0.054054
# 334033     4     8      4     7  0.087500
# 334034    11     8      3     9  0.048649
# 334035     6     5      1     2  0.032787

# %%
from gensim.models.keyedvectors import KeyedVectors

w2v_model = KeyedVectors.load_word2vec_format('../data/external/GoogleNews-vectors-negative300.bin', binary=True)
print('Loaded word embeddings')
# Out:
# Loading word embeddings...

# %%
def similarity(r):

	if (r.word1 in w2v_model.vocab) & (r.word2 in w2v_model.vocab):
		wv1 = w2v_model.word_vec(r.word1)
		wv2 = w2v_model.word_vec(r.word2)
		
		return w2v_model.similarity(r.word1, r.word2)
	else:
		return 100


df['sim'] = df.apply(similarity, axis=1)

# %%
temp = df['word2']
df['word2'] = df['word2'].shift(1)

df['simr'] = df.apply(similarity, axis=1)
#and.. shift back!
df['word2'] = temp

# %%
# remove a words (pairs) that are not in vocabulary
df = df[df['sim'] <= 1.0]
print("Number of remaining word pairs: " +str(len(df)))
print("Mean similariy score: " +str(df['sim'].mean()))
df.tail()
# Out:
# Number of remaining word pairs: 272570
# Mean similariy score: 0.268536773247
#         author     word1        word2        source  sourceID     nt  len1  \
# 334030    4423     sleep       drowsy           sas         7   True     5
# 334031    4298      down        below           sas         7   True     4
# 334032    1732  unneeded  superfluous           gog         5   True     8
# 334033     200      good     riddance  aspiecentral         0  False     4
# 334035    1508    offend        offer           gog         5   True     6
#
#         len2  d_len  edit    n_edit       sim
# 334030     6      1     6  0.098361  0.472259
# 334031     5      1     4  0.097561  0.398525
# 334032    11      3    10  0.054054  0.516668
# 334033     8      4     7  0.087500  0.136230
# 334035     5      1     2  0.032787  0.177787

# %%
# remove a words (pairs) that are not in vocabulary
df = df[df['simr'] <= 1.0]
print("Number of remaining word pairs: " +str(len(df)))
print("Mean similariy score: " +str(df['simr'].mean()))
df.tail()
# Out:
# Number of remaining word pairs: 272557
# Mean similariy score: 0.0820050718481
#         author     word1        word2        source  sourceID     nt  len1  \
# 334030    4423     sleep       drowsy           sas         7   True     5
# 334031    4298      down        below           sas         7   True     4
# 334032    1732  unneeded  superfluous           gog         5   True     8
# 334033     200      good     riddance  aspiecentral         0  False     4
# 334035    1508    offend          NaN           gog         5   True     6
#
#         len2  d_len  edit    n_edit       sim      simr
# 334030     6      1     6  0.098361  0.472259  0.200119
# 334031     5      1     4  0.097561  0.398525  0.077170
# 334032    11      3    10  0.054054  0.516668 -0.017186
# 334033     8      4     7  0.087500  0.136230  0.184280
# 334035     5      1     2  0.032787  0.177787  0.114822

# %% [markdown]
# cats 'n dogs

# %%
#tdf = df
word_list = ['fire','food']
tdf = df[df['word1'].isin(word_list)]

nt = tdf[tdf['nt']].sim
asd = tdf[tdf['nt']==False].sim

print("Number of NT word pairs: " + str(len(nt)))
print("\tMean similarity: " + str(nt.mean()))
print("Number of ASD word pairs: " + str(len(asd)))
print("\tMean similarity: " + str(asd.mean()))

#plot
w1 = np.ones_like(nt)/len(nt)
w2 = np.ones_like(asd)/len(asd)
bins = np.arange(-2,2,0.008)

plt.figure(figsize=(20, 5))
plt.hist(nt, bins=bins, alpha=0.5, label="NT", weights=w1)
plt.hist(asd, bins=bins,alpha=0.5, label="ASD", weights=w2)
plt.title('Histogram of similarity')
plt.xlabel('Similarity')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([-0.1,0.8])
plt.show()
# Out:
# Number of NT word pairs: 610
# 	Mean similarity: 0.272734163174
# Number of ASD word pairs: 223
# 	Mean similarity: 0.291658083549

# %% [markdown]
# What to do??

# %%
aspiescentral = df[df['source']=="aspiecentral"].sim
atu2 = df[df['source']=="atu2"].sim
bleeping_computer = df[df['source']=="bleeping_computer"].sim
classic_comics = df[df['source']=="classic_comics"].sim
ecig = df[df['source']=="ecig"].sim
gog = df[df['source']=="gog"].sim

wrongplanet = df[df['source']=="wrongplanet"].sim


#print("Number of NT word pairs: " + str(len(nt)))
#print("\tMean similarity: " + str(nt.mean()))
#print("Number of ASD word pairs: " + str(len(asd)))
#print("\tMean similarity: " + str(asd.mean()))

#plot
w1 = np.ones_like(aspiescentral)/len(aspiescentral)
w2 = np.ones_like(atu2)/len(atu2)
w3 = np.ones_like(bleeping_computer)/len(bleeping_computer)
w4 = np.ones_like(classic_comics)/len(classic_comics)
w5 = np.ones_like(ecig)/len(ecig)
w6 = np.ones_like(gog)/len(gog)

w10 = np.ones_like(wrongplanet)/len(wrongplanet)

bins = np.arange(-2,2,0.05)

plt.figure(figsize=(20, 5))
plt.hist(aspiescentral, bins=bins, alpha=0.1, label="aspiescentral", weights=w1)
plt.hist(atu2, bins=bins,alpha=0.1, label="atu2", weights=w2)
plt.hist(bleeping_computer, bins=bins,alpha=0.1, label="bleeping_computer", weights=w3)
plt.hist(classic_comics, bins=bins,alpha=0.1, label="classic_comics", weights=w4)
plt.hist(ecig, bins=bins,alpha=0.1, label="ecig", weights=w5)
plt.hist(gog, bins=bins,alpha=0.1, label="gog", weights=w6)

plt.hist(wrongplanet, bins=bins,alpha=0.1, label="wrongplanet", weights=w10)
plt.title('Histogram of similarity')
plt.xlabel('Similarity')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
axes = plt.gca()
axes.set_xlim([-0.1,1.1])
plt.show()
